# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# interpreter is a process that reads code and runs according to it

# %% [markdown]
# foriegn function interface
# - interpreter calls compile functions
