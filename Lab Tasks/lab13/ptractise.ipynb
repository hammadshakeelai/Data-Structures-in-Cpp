# %% [markdown]
# psuedo code

# %% [markdown]
# read txt
# store in linked list
# sort
# store in file

# %% [markdown]
#     //learn file reading with me
#     //	ifstream cin_("filename.txt");
#     //	string num;
#     //	cin_>>num;
#     //	cout<<num;
#     //	int n;
#     //	cin_>>n;
#     //	cout<<n*8;
#     //----
