# %% [markdown]
# # Linked List

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None
    def insert(self,value):
        if(self.head == None):
            self.head = Node(value)
            print(f"{value} inserted")
        else:
            curr = self.head
            while(curr.next):
                curr = curr.next
            curr.next = Node(value) 
            print(f"{value} inserted")
            # print(self.head.data," ",self.head.next.data)
    def printl(self):
        if(self.head == None):
            print("Empty Linked List")
            return
        curr = self.head
        while(curr != None):
            print(curr.data," -> ",end="",sep="")
            curr = curr.next
        print("NULL")

dummy: LinkedList = LinkedList()
dummy.insert(5)
dummy.insert(6)
dummy.insert(7)
dummy.printl()
# Out:
# 5 inserted
# 6 inserted
# 7 inserted
# 5 -> 6 -> 7 -> NULL

# %%
dummy = 0

# %% [markdown]
# sda
# ├─sda1
# │    └─sda1
# │      ├─sda2
# │      └─sda3
# ├─sda2
# └─sda3

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.right = None
        self.left = None
    def insert(self,value):
        if(self.head == None):
            self.head = Node(value)
            print(f"{value} inserted")
        else:
            if (self.head.data > value):
                insert(left.)
